# %%
BASE = "https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/05-monitoring/code"

files = [
    "Makefile",
    "app.py",
    "assistant.py",
    "dashboard.py",
    "db_feedback.py",
    "db_init.py",
    "db_query.py",
    "db_save.py",
    "evaluation_utils.py",
    "generate_data.py",
    "ingest.py",
    "judge.py",
    "main.py",
    "metrics.py",
    "pyproject.toml",
    "rag_helper.py",
]

# %%
for f in files:
    # !wget -P lessons/lesson05/code {BASE}/{f}
# Out:
# --2026-07-20 11:38:14--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/05-monitoring/code/Makefile
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 415 [text/plain]
# Saving to: ‘lessons/lesson05/code/Makefile’
#
# Makefile            100%[===================>]     415  --.-KB/s    in 0s
#
# 2026-07-20 11:38:14 (36.0 MB/s) - ‘lessons/lesson05/code/Makefile’ saved [415/415]
#
# --2026-07-20 11:38:14--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/05-monitoring/code/app.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# ...

# %%
# %%bash
#
# cat > README.md <<'EOF'
# # Lesson 05
#
# Source: https://github.com/DataTalksClub/llm-zoomcamp/tree/main/05-monitoring
#
# This local copy includes only `code/`.
# EOF
